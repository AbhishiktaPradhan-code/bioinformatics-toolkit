# %%
from Bio import SeqIO

short_sequences = []  # Setup an empty list
for record in SeqIO.parse("ls_orchid.fasta.fasta", "fasta"):
    print(f"{record.id}: {len(record.seq)} bp")  # Print length
    if len(record.seq) < 300:
        short_sequences.append(record)

print("Found %i short sequences" % len(short_sequences))
# Out:
# gi|2765658|emb|Z78533.1|CIZ78533: 740 bp
# gi|2765657|emb|Z78532.1|CCZ78532: 753 bp
# gi|2765656|emb|Z78531.1|CFZ78531: 748 bp
# gi|2765655|emb|Z78530.1|CMZ78530: 744 bp
# gi|2765654|emb|Z78529.1|CLZ78529: 733 bp
# gi|2765652|emb|Z78527.1|CYZ78527: 718 bp
# gi|2765651|emb|Z78526.1|CGZ78526: 730 bp
# gi|2765650|emb|Z78525.1|CAZ78525: 704 bp
# gi|2765649|emb|Z78524.1|CFZ78524: 740 bp
# gi|2765648|emb|Z78523.1|CHZ78523: 709 bp
# gi|2765647|emb|Z78522.1|CMZ78522: 700 bp
# gi|2765646|emb|Z78521.1|CCZ78521: 726 bp
# gi|2765645|emb|Z78520.1|CSZ78520: 753 bp
# gi|2765644|emb|Z78519.1|CPZ78519: 699 bp
# gi|2765643|emb|Z78518.1|CRZ78518: 658 bp
# gi|2765642|emb|Z78517.1|CFZ78517: 752 bp
# gi|2765641|emb|Z78516.1|CPZ78516: 726 bp
# gi|2765640|emb|Z78515.1|MXZ78515: 765 bp
# gi|2765639|emb|Z78514.1|PSZ78514: 755 bp
# gi|2765638|emb|Z78513.1|PBZ78513: 742 bp
# gi|2765637|emb|Z78512.1|PWZ78512: 762 bp
# gi|2765636|emb|Z78511.1|PEZ78511: 745 bp
# gi|2765635|emb|Z78510.1|PCZ78510: 750 bp
# ...

# %%
from Bio import SeqIO

fasta_file = "sequence.fasta"  # your file path

for record in SeqIO.parse(fasta_file, "fasta"):
    print("ID:", record.id)
    print("Description:", record.description)
    print("Sequence:", record.seq)
    print("Length:", len(record.seq))
    print("-" * 40)
# Out:
# ID: M85050.1
# Description: M85050.1 Pseudoterranova decipiens (frameshift mutated) hemoglobin mRNA, complete cds
# Sequence: ...
# Length: 1353
# ----------------------------------------
